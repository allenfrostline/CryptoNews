# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv('misc/results.csv', index_col=0)

# %%
result[(result['size'] == 'binary') & (result['strategy'] == 'Strategy')]
# Out:
#      lookback_window  minimum_occurrence  minimum_length  alpha    size  \
# 3                 20                  10               1   0.05  binary
# 15                20                  10               1   0.10  binary
# 27                20                  10               1   0.20  binary
# 39                20                  10               3   0.05  binary
# 51                20                  10               3   0.10  binary
# 63                20                  10               3   0.20  binary
# 75                20                  10               5   0.05  binary
# 87                20                  10               5   0.10  binary
# 99                20                  10               5   0.20  binary
# 111               20                  50               1   0.05  binary
# 123               20                  50               1   0.10  binary
# 135               20                  50               1   0.20  binary
# ...

# %% [markdown]
# Assigning position sizes on continuous scale rather than discrete usually gives smaller/smallest maximum drawdown
